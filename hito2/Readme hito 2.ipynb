# %% [markdown]
# ## Clasificación de Anfibios mediante Deep Learning ##

# %% [markdown]
# Este proyecto tiene como objetivo desarrollar un modelo de aprendizaje profundo (Deep Learning) capaz de identificar especies de anfibios a partir de grabaciones de audio. El proceso abarca desde el preprocesamiento de señales de audio hasta el entrenamiento y evaluación de una Red Neuronal Convolucional (CNN)

# %% [markdown]
# ### Tabla de Contenidos ###

# %% [markdown]
# 1. Descripción del Proyecto
# 2. Estructura del Repositorio
# 3. Requisitos
# 4. Resultados
# 5. Autores

# %% [markdown]
# ## Descripción del Proyecto ##
# El proyecto utiliza un dataset de audio de diversas especies de anfibios. Las señales de audio crudas (.wav) son transformadas en espectrogramas de Mel, que sirven como imágenes de entrada para una red neuronal. El objetivo final es clasificar correctamente la especie a la que pertenece cada audio.

# %% [markdown]
# ## Estructura del Repositorio
#
# ```bash
# .
# ├── data/
# │   ├── raw/                 # Audios originales en formato .wav
# │   └── processed/           # Espectrogramas procesados (.npz) y metadata.csv
# ├── notebooks/
# │   ├── Hito_2_Procesamiento.ipynb   # Notebook del Hito 2
# │   └── Hito_3_Entrenamiento.ipynb   # Notebook del Hito 3
# ├── README.md                # Este archivo
# └── requirements.txt         # Librerías necesarias

# %% [markdown]
# ### Celda 4 (Markdown): Requisitos e Instalación
#
#
# Para ejecutar este proyecto, necesitas Python 3.8 o superior. Las principales librerías utilizadas son:
#
# * `numpy`
# * `pandas`
# * `librosa` (para procesamiento de audio)
# * `matplotlib` / `seaborn` (para visualización)
# * `tensorflow` (para el modelo de Deep Learning)
# * `scikit-learn` (para métricas y preprocesamiento)
#
# **Instalación rápida:**
# ```bash
# pip install numpy pandas librosa matplotlib seaborn tensorflow scikit-learn

# %%
## Hito 2 - Procesamiento
Aquí detallas lo que hiciste en la primera parte:

```markdown
## Hito 2: Procesamiento de Datos 🛠️

En esta etapa, nos enfocamos en transformar los audios crudos en una representación visual útil para el modelo.

**Actividades realizadas:**
1.  **Carga de Audios:** Lectura de archivos `.wav` usando `librosa`.
2.  **Extracción de Características:** Conversión de audio a **Espectrogramas de Mel** (representación tiempo-frecuencia logarítmica). 
3.  **Almacenamiento:** Los espectrogramas se guardaron como archivos comprimidos `.npz` para una carga eficiente.
4.  **Metadata:** Se generó un archivo `metadata.csv` que vincula cada archivo procesado con su etiqueta (especie).
5.  **Validación:** Se visualizó una muestra de los espectrogramas para asegurar que la conversión fue correcta y se analizó el balance de clases.

**Script principal:** `Procesamiento de Señal y Extracción de Características.ipynb`
